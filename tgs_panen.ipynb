# %%
data_panen = {
    'lokasi1' : {
        'nama_lokasi' : 'Kebun A',
        'hasil_panen' : {
            'padi' : 1200,
            'jagung' : 800, 
            'kedelai' : 500
        }
    },
    'lokasi2' : {
        'nama_lokasi' : 'Kebun B',
        'hasil_panen' : {
            'padi' : 1500,
            'jagung' : 900,
            'kedelai' : 450
        }
    },

    'lokasi3': {
        'nama_lokasi' : 'Kebun C',
        "hasil_panen" : {
            'padi' : 1100,
            'jagung' : 750,
            'kedelai' : 600
        }
    },

    'lokasi4' : {
        'nama_lokasi' : 'Kebun D',
        'hasil_panen' : {
            'padi' : 1300,
            'jagung' : 850,
            'kedelai' : 550
        }
    },

    'lokasi5' : {
        'nama_lokasi' : 'Kebun E',
        'hasil_panen' : {
            'padi' : 1400,
            'jagung' : 950,
            'kedelai' : 480
        }
    }
}

# %%
# 1. Tampilkan seluruh data dari data_panen termasuk nama lokasi dan hasil panen masing-masing.

print(data_panen)
# Out:
# {'lokasi1': {'nama_lokasi': 'Kebun A', 'hasil_panen': {'padi': 1200, 'jagung': 800, 'kedelai': 500}}, 'lokasi2': {'nama_lokasi': 'Kebun B', 'hasil_panen': {'padi': 1500, 'jagung': 900, 'kedelai': 450}}, 'lokasi3': {'nama_lokasi': 'Kebun C', 'hasil_panen': {'padi': 1100, 'jagung': 750, 'kedelai': 600}}, 'lokasi4': {'nama_lokasi': 'Kebun D', 'hasil_panen': {'padi': 1300, 'jagung': 850, 'kedelai': 550}}, 'lokasi5': {'nama_lokasi': 'Kebun E', 'hasil_panen': {'padi': 1400, 'jagung': 950, 'kedelai': 480}}}

# %%
# 2. Tampilkan jumlah hasil panen jagung dari lokasi2.
print(f"Hasil Panen Jagung dari Lokasi 2: {data_panen['lokasi2']['hasil_panen']['jagung']}")
# Out:
# Hasil Panen Jagung dari Lokasi 2: 900

# %%
# 3. Tampilkan nama lokasi dari lokasi3.
print(f"Nama Lokasi 3: {data_panen['lokasi3']['nama_lokasi']}")
# Out:
# Nama Lokasi 3: Kebun C

# %%
# 4. Masukkan Jumlah Hasil Panen Padi dan Kedelai Setiap Lokasi ke Dalam Variabel yang Berbeda:
padi = {}
kedelai = {}

for key, lokasi in data_panen.items():
    padi[key] = lokasi['hasil_panen']['padi']
    kedelai[key] = lokasi['hasil_panen']['kedelai']

print(f"Data Padi: {padi}")
print(f"Data Kedelai: {kedelai}")
# Out:
# Data Padi: {'lokasi1': 1200, 'lokasi2': 1500, 'lokasi3': 1100, 'lokasi4': 1300, 'lokasi5': 1400}
# Data Kedelai: {'lokasi1': 500, 'lokasi2': 450, 'lokasi3': 600, 'lokasi4': 550, 'lokasi5': 480}

# %%
# 5. Buat variabel terpisah untuk menyimpan jumlah hasil panen padi dan kedelai dari setiap lokasi.
padi_lokasi1 = data_panen['lokasi1']['hasil_panen']['padi']
kedelai_lokasi1 = data_panen['lokasi1']['hasil_panen']['kedelai']

padi_lokasi2 = data_panen['lokasi2']['hasil_panen']['padi']
kedelai_lokasi2 = data_panen['lokasi2']['hasil_panen']['kedelai']

padi_lokasi3 = data_panen['lokasi3']['hasil_panen']['padi']
kedelai_lokasi3 = data_panen['lokasi3']['hasil_panen']['kedelai']

padi_lokasi4 = data_panen['lokasi4']['hasil_panen']['padi']
kedelai_lokasi4 = data_panen['lokasi4']['hasil_panen']['kedelai']

padi_lokasi5 = data_panen['lokasi5']['hasil_panen']['padi']
kedelai_lokasi5 = data_panen['lokasi5']['hasil_panen']['kedelai']

# %%
# 6. Buat Percabangan Jika jumlah hasil panen padi lebih dari 1300 atau jagung lebih dari 800 di suatu lokasi, maka lokasi tersebut memerlukan perhatian khusus. Jika tidak, maka lokasi tersebut dalam kondisi baik.
# Push hasil pengerjaan kedalam GITz
if padi_lokasi1 > 1300 or data_panen['lokasi1']['hasil_panen']['jagung'] > 800:
    print("Kebun A memerlukan perhatian khusus")
else:
    print("Kebun A dalam kondisi baik")

if padi_lokasi2 > 1300 or data_panen['lokasi2']['hasil_panen']['jagung'] > 800:
    print("Kebun B memerulkan perhatian Khusus")
else:
    print("Kebun B dlaam kondisi baik")

if padi_lokasi3 > 1300 or data_panen['lokasi3']['hasil_panen']['jagung'] > 800:
    print("Kebun C memerulkan perhatian Khusus")
else:
    print("Kebun C dlaam kondisi baik")

if padi_lokasi4 > 1300 or data_panen['lokasi4']['hasil_panen']['jagung'] > 800:
    print("Kebun D memerulkan perhatian Khusus")
else:
    print("Kebun D dlaam kondisi baik")

if padi_lokasi5 > 1300 or data_panen['lokasi5']['hasil_panen']['jagung'] > 800:
    print("Kebun E memerulkan perhatian Khusus")
else:
    print("Kebun E dlaam kondisi baik")
# Out:
# Kebun A dalam kondisi baik
# Kebun B memerulkan perhatian Khusus
# Kebun C dlaam kondisi baik
# Kebun D memerulkan perhatian Khusus
# Kebun E memerulkan perhatian Khusus

# %%
print("Perubahan dari branch Baru")
